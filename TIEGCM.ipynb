# %% [markdown]
# # TIEGCM analysis and visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from netCDF4 import Dataset

# %%
from plotly.offline import plot, iplot
import plotly.graph_objs as go

from plotly.graph_objs import Layout

# %%
import plotly

# %%
import scipy
import numpy as np

from scipy.interpolate import griddata, LinearNDInterpolator

# %%
import pandas as pd

# %%
from util import *

# %%
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
directory = "sample_data/jasoon_shim_052317_IT_10/out/"

# %%
pfile = directory + 'p001.nc'
sfile = directory + 's001.nc'
print pfile
print sfile
# Out:
# sample_data/jasoon_shim_052317_IT_10/out/p001.nc
# sample_data/jasoon_shim_052317_IT_10/out/s001.nc

# %%
a = range(5)
a
# Out:
# [0, 1, 2, 3, 4]

# %%
a[:4]
# Out:
# [0, 1, 2, 3]

# %%
rootgrp = Dataset(sfile, 'r')

# %%
len(rootgrp.variables['ilev'])
# Out:
# 29

# %%
dimensional = group_dimensional(rootgrp)
dimensional.keys()
# Out:
# ['0-d', '3-d', '4-d', '1-d', '2-d']

# %%
describe(rootgrp, dimensional['0-d'])
# Out:
#               units                                          long_name shape  \
# timestep    seconds                                           timestep    ()
# p0        millibars                                 Reference pressure    ()
# p0_model  microbars          Reference pressure (as used by the model)    ()
# grav           cm/s                         gravitational acceleration    ()
# LBC            None  Interface level of t,u,v lower boundary condition    ()
#
#                    min           max
# timestep  6.000000e+01  6.000000e+01
# p0        5.000000e-07  5.000000e-07
# p0_model  5.000000e-04  5.000000e-04
# grav      8.700000e+02  8.700000e+02
# LBC      -7.000000e+00 -7.000000e+00

# %%
describe(rootgrp, dimensional['1-d'])
# Out:
#                                           units  \
# time              minutes since 2012-10-1 0:0:0
# lon                                degrees_east
# lat                               degrees_north
# lev
# ilev
# mlon                               degrees_east
# mlat                              degrees_north
# mlev
# imlev
# year                                       None
# day                                        None
# calendar_advance                           None
# iter                                       None
# ntask_mpi                                  None
# coupled_cmit                               None
# ut                                        hours
# f107d                            1.e-22 W/m2/Hz
# f107a                            1.e-22 W/m2/Hz
# hpower                                       GW
# ctpoten                                      kV
# Kp                                         None
# bximf                                        nT
# byimf                                        nT
# bzimf                                        nT
# swvel                                      km/s
# swden                                       cm3
# al                                           nT
# colfac                                     None
# joulefac                                   None
# e1                                   ergs/cm2/s
# e2                                   ergs/cm2/s
# h1                                      degrees
# h2                                      degrees
# alfac                                       keV
# ec                                 ergs/cm**2/s
# alfad                                       keV
# ed                                 ergs/cm**2/s
# crit1                                       deg
# crit2                                       deg
#
#                                                           long_name  shape  \
# time                                                           time  (24,)
# lon                             geographic longitude (-west, +east)  (72,)
# lat                            geographic latitude (-south, +north)  (36,)
# lev                                                 midpoint levels  (29,)
# ilev                                               interface levels  (29,)
# mlon                              magnetic longitude (-west, +east)  (81,)
# mlat                             magnetic latitude (-south, +north)  (97,)
# mlev                                       magnetic midpoint levels  (32,)
# imlev                                     magnetic interface levels  (32,)
# year                                                  calendar year  (24,)
# day                                                    calendar day  (24,)
# calendar_advance  calendar advance flag (1 if advancing calendar...  (24,)
# iter                     number of time steps from model time 0,0,0  (24,)
# ntask_mpi                                       Number of MPI tasks  (24,)
# coupled_cmit               1 if coupled with CISM/CMIT, 0 otherwise  (24,)
# ut                 universal time (from model time hour and minute)  (24,)
# f107d                                      Daily 10.7 cm solar flux  (24,)
# f107a                             81-day average 10.7 cm solar flux  (24,)
# hpower                                            Hemispheric power  (24,)
# ctpoten                                        Cross-tail potential  (24,)
# Kp                                                         Kp index  (24,)
# bximf                                           BX component of IMF  (24,)
# byimf                                           BY component of IMF  (24,)
# bzimf                                           BZ component of IMF  (24,)
# swvel                                           Solar wind velocity  (24,)
# swden                                            Solar wind density  (24,)
# al                            Lower magnetic auroral activity index  (24,)
# colfac                                 ion/neutral collision factor  (24,)
# joulefac                                       joule heating factor  (24,)
# e1                    Peak energy flux in noon sector of the aurora  (24,)
# e2                Peak energy flux in midnight sector of the aurora  (24,)
# h1                     Gaussian half-width of the noon auroral oval  (24,)
# h2                 Gaussian half-width of the midnight auroral oval  (24,)
# alfac             Characteristic Maxwellian energy of polar cusp...  (24,)
# ec                      Column energy input of polar cusp electrons  (24,)
# alfad             Characteristic Maxwellian energy of drizzle el...  (24,)
# ed                         Column energy input of drizzle electrons  (24,)
# crit1                                critical cross-over latitude 1  (24,)
# crit2                                critical cross-over latitude 2  (24,)
#
#                            min           max
# time              2.000000e+01  4.800000e+02
# lon              -1.800000e+02  1.750000e+02
# lat              -8.750000e+01  8.750000e+01
# lev              -6.750000e+00  7.250000e+00
# ilev             -7.000000e+00  7.000000e+00
# mlon             -1.800000e+02  1.800000e+02
# mlat             -9.000000e+01  9.000000e+01
# mlev             -8.250000e+00  7.250000e+00
# imlev            -8.500000e+00  7.000000e+00
# year              2.012000e+03  2.012000e+03
# day               2.750000e+02  2.750000e+02
# calendar_advance  1.000000e+00  1.000000e+00
# iter              3.960200e+05  3.964800e+05
# ntask_mpi         6.400000e+01  6.400000e+01
# coupled_cmit      0.000000e+00  0.000000e+00
# ut                3.333333e-01  8.000000e+00
# f107d             1.298603e+02  1.325850e+02
# f107a             1.191904e+02  1.192891e+02
# hpower            1.794346e+01  1.125018e+02
# ctpoten           7.606373e+01  1.386415e+02
# Kp                3.416667e+00  6.677778e+00
# bximf             1.709375e-01  7.478125e+00
# byimf            -4.840908e-01  1.414769e+01
# bzimf            -1.259680e+01  3.083826e+00
# swvel             3.794346e+02  4.166166e+02
# swden             7.127000e+00  1.785622e+01
# al                1.000000e+36  1.000000e+36
# colfac            1.500000e+00  1.500000e+00
# joulefac          1.500000e+00  1.500000e+00
# e1                1.591267e+00  3.970024e+00
# e2                2.973781e+00  1.337520e+01
# h1                2.350000e+00  2.350000e+00
# h2                3.504435e+00  5.312546e+00
# alfac             1.000000e-01  1.000000e-01
# ec                7.204424e-02  1.987525e-01
# alfad             5.000000e-01  5.000000e-01
# ed                1.196608e-02  6.870110e-02
# crit1             1.879271e+01  2.199040e+01
# crit2             3.379271e+01  3.699040e+01

# %% [markdown]
# Each file represents 8 hours  of simulation time. There are 24 time steps in each file, corresponding to one step every 20 minutes.

# %%
rootgrp.variables['time']
# Out:
# <type 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     long_name: time
#     units: minutes since 2012-10-1 0:0:0
#     initial_year: 2012
#     initial_day: 275
#     initial_mtime: [275   0   0]
# unlimited dimensions: time
# current shape = (24,)
# filling off

# %%
describe(rootgrp, 
         ['time', 'ilev', 'lev','lat', 'lon'], 
         ['units', 'short_name', 'long_name', 'shape', 'formula'])
# Out:
#                               units short_name  \
# time  minutes since 2012-10-1 0:0:0       None
# ilev                                  ln(p0/p)
# lev                                   ln(p0/p)
# lat                   degrees_north       None
# lon                    degrees_east       None
#
#                                  long_name  shape                    formula  \
# time                                  time  (24,)                       None
# ilev                      interface levels  (29,)  p(k) = p0 * exp(-ilev(k))
# lev                        midpoint levels  (29,)   p(k) = p0 * exp(-lev(k))
# lat   geographic latitude (-south, +north)  (36,)                       None
# lon    geographic longitude (-west, +east)  (72,)                       None
#
#          min     max
# time   20.00  480.00
# ilev   -7.00    7.00
# lev    -6.75    7.25
# lat   -87.50   87.50
# lon  -180.00  175.00

# %% [markdown]
# ### 2D variables

# %%
describe(rootgrp, dimensional['2-d'])
# Out:
#                                 units  \
# mtime               day, hour, minute
# write_date                       None
# dtide                            None
# sdtide                           None
# ncep_ncfile                      None
# gpi_ncfile                       None
# saber_ncfile                     None
# tidi_ncfile                      None
# bgrddata_ncfile                  None
# ctmt_ncfile                      None
# see_ncfile                       None
# imf_ncfile                       None
# gswm_mi_di_ncfile                None
# gswm_mi_sdi_ncfile               None
# gswm_nm_di_ncfile                None
# gswm_nm_sdi_ncfile               None
# mag                           degrees
#
#                                                           long_name  \
# mtime                               model times (day, hour, minute)
# write_date                   Date and time each history was written
# dtide                amplitude and phase of diurnal tide mode (1,1)
# sdtide                   amplitudes and phases of semi-diurnal tide
# ncep_ncfile                                          ncep data file
# gpi_ncfile                            GeoPhysical Indices data file
# saber_ncfile                                    SABER lbc data file
# tidi_ncfile                                      TIDI lbc data file
# bgrddata_ncfile                            background lbc data file
# ctmt_ncfile                                      CTMT lbc data file
# see_ncfile                                      TIMED SEE data file
# imf_ncfile                                            IMF data file
# gswm_mi_di_ncfile            GSWM migrating diurnal tides data file
# gswm_mi_sdi_ncfile      GSWM migrating semi-diurnal tides data file
# gswm_nm_di_ncfile        GSWM non-migrating diurnal tides data file
# gswm_nm_sdi_ncfile  GSWM non-migrating semi-diurnal tides data file
# mag                       lat,lon coordinates of S,N magnetic poles
#
#                          shape           min           max
# mtime                  (24, 3)  0.000000e+00  2.750000e+02
# write_date            (24, 24)           NaN           NaN
# dtide                  (24, 2)  0.000000e+00  0.000000e+00
# sdtide                (24, 10)  0.000000e+00  0.000000e+00
# ncep_ncfile         (24, 1024)           NaN           NaN
# gpi_ncfile          (24, 1024)           NaN           NaN
# saber_ncfile        (24, 1024)           NaN           NaN
# tidi_ncfile         (24, 1024)           NaN           NaN
# bgrddata_ncfile     (24, 1024)           NaN           NaN
# ctmt_ncfile         (24, 1024)           NaN           NaN
# see_ncfile          (24, 1024)           NaN           NaN
# imf_ncfile          (24, 1024)           NaN           NaN
# gswm_mi_di_ncfile   (24, 1024)           NaN           NaN
# gswm_mi_sdi_ncfile  (24, 1024)           NaN           NaN
# gswm_nm_di_ncfile   (24, 1024)           NaN           NaN
# gswm_nm_sdi_ncfile  (24, 1024)           NaN           NaN
# mag                     (2, 2)  9.969210e+36  9.969210e+36

# %% [markdown]
# ### 3D shape
# 3d arrays correspond in shape to [time, lat, lon]

# %%
describe(rootgrp, dimensional['3-d'])
# Out:
#                   units                                  long_name  \
# TEC               1/cm2                TEC: Total Electron Content
# QJOULE_INTEG  erg/cm2/s            Height-integrated Joule Heating
# EFLUX         erg/cm2/s                         Aurora Energy Flux
# HMF2                 km               HMF2: Height of the F2 Layer
# NMF2              1/cm3         NMF2: Peak Density of the F2 Layer
# TLBC                  K             Lower boundary condition of TN
# ULBC               cm/s             Lower boundary condition of UN
# VLBC               cm/s             Lower boundary condition of VN
# TLBC_NM               K  Lower boundary condition of TN (TIME N-1)
# ULBC_NM            cm/s  Lower boundary condition of UN (TIME N-1)
# VLBC_NM            cm/s  Lower boundary condition of VN (TIME N-1)
#
#                      shape           min           max
# TEC           (24, 36, 72)  1.375009e+12  6.294050e+13
# QJOULE_INTEG  (24, 36, 72)  4.280629e-04  7.633630e+01
# EFLUX         (24, 36, 72)  0.000000e+00  1.332358e+01
# HMF2          (24, 36, 72)  1.236165e+02  5.223236e+02
# NMF2          (24, 36, 72)  4.939089e+04  2.579142e+06
# TLBC          (24, 36, 72)  1.564640e+02  2.036720e+02
# ULBC          (24, 36, 72) -5.879154e+03  4.315232e+03
# VLBC          (24, 36, 72) -7.275964e+03  7.556053e+03
# TLBC_NM       (24, 36, 72)  1.564839e+02  2.036565e+02
# ULBC_NM       (24, 36, 72) -5.873854e+03  4.313503e+03
# VLBC_NM       (24, 36, 72) -7.270802e+03  7.550078e+03

# %% [markdown]
# 4-d shape corresponds to [time, ilev, lat, lon]

# %%
describe(rootgrp, dimensional['4-d'])
# Out:
#              units                         long_name             shape  \
# TN               K               NEUTRAL TEMPERATURE  (24, 29, 36, 72)
# UN            cm/s        NEUTRAL ZONAL WIND (+EAST)  (24, 29, 36, 72)
# VN            cm/s  NEUTRAL MERIDIONAL WIND (+NORTH)  (24, 29, 36, 72)
# O1             mmr                     ATOMIC OXYGEN  (24, 29, 36, 72)
# NO             mmr                      NITRIC OXIDE  (24, 29, 36, 72)
# N4S            mmr                               N4S  (24, 29, 36, 72)
# HE             mmr                            HELIUM  (24, 29, 36, 72)
# NE            cm-3                  ELECTRON DENSITY  (24, 29, 36, 72)
# TE               K              ELECTRON TEMPERATURE  (24, 29, 36, 72)
# TI               K                   ION TEMPERATURE  (24, 29, 36, 72)
# O2             mmr                  MOLECULAR OXYGEN  (24, 29, 36, 72)
# O2P_ELD       None                              None  (24, 29, 36, 72)
# OMEGA          s-1                   VERTICAL MOTION  (24, 29, 36, 72)
# POTEN        volts                ELECTRIC POTENTIAL  (24, 29, 36, 72)
# UI_ExB        cm/s            UI: Zonal ExB Velocity  (24, 29, 36, 72)
# VI_ExB        cm/s       VI: Meridional ExB Velocity  (24, 29, 36, 72)
# WI_ExB        cm/s         WI: Vertical ExB Velocity  (24, 29, 36, 72)
# OP            cm-3                            O+ ION  (24, 29, 36, 72)
# N2P_ELD       None                              None  (24, 29, 36, 72)
# NPLUS         None                              None  (24, 29, 36, 72)
# NOP_ELD       None                              None  (24, 29, 36, 72)
# SIGMA_PED      S/m  SIGMA_PED: Pedersen Conductivity  (24, 29, 36, 72)
# SIGMA_HAL      S/m      SIGMA_HAL: Hall Conductivity  (24, 29, 36, 72)
# DEN          g/cm3                     Total Density  (24, 29, 36, 72)
# QJOULE     erg/g/s             QJOULE: Joule Heating  (24, 29, 36, 72)
# Z               cm               GEOPOTENTIAL HEIGHT  (24, 29, 36, 72)
# ZG              cm               Geometric Height ZG  (24, 29, 36, 72)
# O_N2          none                        O/N2 RATIO  (24, 29, 36, 72)
# N2D_ELD       None                              None  (24, 29, 36, 72)
# O2N           None                              None  (24, 29, 36, 72)
# N2N           None                              None  (24, 29, 36, 72)
# ZMAG            km                 ZMAG from pdynamo  (24, 32, 97, 81)
#
#                     min           max
# TN         1.475614e+02  1.385325e+03
# UN        -6.970348e+04  6.350308e+04
# VN        -7.142820e+04  6.891355e+04
# O1         1.494940e-03  9.463220e-01
# NO         3.516701e-08  1.583549e-03
# N4S        1.000000e-12  2.071025e-02
# HE         1.148865e-06  5.126053e-01
# NE         7.747815e+02  2.578788e+06
# TE         1.475751e+02  4.280271e+03
# TI         1.475666e+02  3.397951e+03
# O2         9.892697e-07  2.323366e-01
# O2P_ELD    0.000000e+00  2.115289e+05
# OMEGA     -4.225365e-04  4.649109e-04
# POTEN     -7.621162e+04  6.694512e+04
# UI_ExB    -1.229434e+05  1.148719e+05
# VI_ExB    -1.103654e+05  8.299840e+04
# WI_ExB    -2.758941e+04  2.254067e+04
# OP         0.000000e+00  2.608035e+06
# N2P_ELD   -2.242308e-01  1.591780e+04
# NPLUS     -1.050485e+02  1.917729e+04
# NOP_ELD   -2.301872e-02  2.600645e+05
# SIGMA_PED  5.591569e-10  9.983176e-04
# SIGMA_HAL  4.412553e-15  1.642709e-03
# DEN        6.802406e-17  1.213197e-09
# QJOULE     1.107774e-04  3.093079e+06
# Z          9.568750e+06  7.278292e+07
# ZG         9.568750e+06  7.236862e+07
# O_N2       1.951186e-03  8.608996e+05
# N2D_ELD   -6.314686e-06  3.691778e-03
# O2N        1.672602e+01  4.232090e+12
# N2N        1.272531e+00  1.611608e+13
# ZMAG       9.000000e+01  6.806738e+02

# %%
lat = np.array(rootgrp.variables['lat'])
lon = np.array(rootgrp.variables['lon'])
ilev = np.array(rootgrp.variables['ilev'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-401ce4d62d21> in <module>()
# ----> 1 lat = np.array(rootgrp.variables['lat'])
#       2 lon = np.array(rootgrp.variables['lon'])
#       3 ilev = np.array(rootgrp.variables['ilev'])
#
# NameError: name 'rootgrp' is not defined

# %%
z = np.array(rootgrp.variables['Z'])

# %%
limits = pd.DataFrame(dict(latitude = [lat.min(), lat.max()], 
                           longitude = [lon.min(), lon.max()],
                          z =[ z.min(), z.max()]), index = ['min', 'max'])
limits
# Out:
#      latitude  longitude           z
# min     -87.5     -180.0   9568750.0
# max      87.5      175.0  72782920.0

# %%
point = (0, 0, (z.max() + z.min())/2)
point
# Out:
# (0, 0, 41175836.0)

# %%
from collections import namedtuple

# %%
Point4D = namedtuple("Point4D", ['time','height', 'latitude','longitude'])
Point3D = namedtuple("Point3D", ['height', 'latitude','longitude'])
Point2D =  namedtuple("Point2D", ['latitude','longitude'])

point = Point3D( height=41175836.0, latitude=87, longitude=170)
point2D = Point2D(latitude=87, longitude=170)

# %%
point
# Out:
# Point3D(height=41175836.0, latitude=87, longitude=170)

# %% [markdown]
# # Visualize results from tiegcm
#
# ## Fixed height interpolation

# %%
lat, lon = np.meshgrid(tiegcm.lat[1:-1], tiegcm.lon)

# %%
z_mid = 400*1e3*1e2 #cm

# %%
points = [Point3D(z_mid, p[0], p[1]) for p in zip(lat.ravel(), lon.ravel())]
points[330]
print len(points)
# Out:
# 2482

# %%
points[0]
# Out:
# Point3D(height=41175836.0, latitude=-82.5, longitude=-180.0)

# %%
variable = 'DEN'

# %%
ne = [tiegcm.time_interpolate(p, variable, 3.5) for p in points]

# %%
min(ne), max(ne)
# Out:
# (1.9747471576326707e-15, 6.1439420816660559e-15)

# %%
phi = lon*np.pi/180
phi.min(), phi.max()
# Out:
# (-3.1415926535897931, 3.1415926535897931)

# %%
theta = lat*np.pi/180
theta.min(), theta.max()
# Out:
# (-1.4398966328953218, 1.4398966328953218)

# %%
r_E = 637.1e6
r = (r_E + z_mid)/r_E
r
# Out:
# 1.062784492230419

# %%
x = r * np.cos(theta) * np.cos(phi)
y = r * np.cos(theta) * np.sin(phi)
z = r * np.sin(theta)

# %%
lat.shape
# Out:
# (73, 34)

# %%
np.array(ne).max()
# Out:
# 6.1439420816660559e-15

# %%
trace1 = go.Surface(
    x = x,
    y = y,
    z = z,
    surfacecolor = np.array(ne).reshape(lat.shape),
    colorbar = dict(title = variable + ' [gm/cm3]')
)

# %%
def to_range(x, start, limit):
    result  = start + (x - start) % (limit - start)
    print x, '->', [start, limit], '=', result
    return result
    

r = [0, 2.5]
to_range(3.0, *r)
to_range(-.1, *r)
# Out:
# 3.0 -> [0, 2.5] = 0.5
# -0.1 -> [0, 2.5] = 2.4
# 2.4

# %%
r = [-180, 180]
to_range(185, *r)
to_range(-185,*r)
# Out:
# 185 -> [-180, 180] = -175
# -185 -> [-180, 180] = 175
# 175

# %%
r = [tiegcm.lon.min(), tiegcm.lon.max()]
to_range(180, *r)
to_range(170, *r)
to_range(176, *r)
# Out:
# 180 -> [-180.0, 180.0] = -180.0
# 170 -> [-180.0, 180.0] = 170.0
# 176 -> [-180.0, 180.0] = 176.0
# 176.0

# %% [markdown]
# We need to get the min longitude slice and append it to the variable

# %%
fig = go.Figure(data=[trace1], layout = go.Layout(title = 'TIEGCM'))

iplot(fig)
# Out:
# <div id="e6275926-534f-46eb-b767-3864fcd97639" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e6275926-534f-46eb-b767-3864fcd97639", [{"colorbar": {"title": "DEN [gm/cm3]"}, "surfacecolor": [[4.5915436268635874e-15, 4.3122890625545405e-15, 4.084239933609394e-15, 4.1000449398763454e-15, 4.345285411464792e-15, 4.876237563131795e-15, 5.218528874201369e-15, 5.453850070327588e-15, 5.513106484337073e-15, 5.5579360814575606e-15, 5.513343740022005e-15, 5.427660725273215e-15, 5.301167309353536e-15, 5.211692718948189e-15, 5.1645432285069004e-15, 5.178230257517629e-15, 5.2133476307173134e-15, 5.2661237060214335e-15, 5.303117748741897e-15, 5.337383458026924e-15, 5.329864984989528e-15, 5.315084766773517e-15, 5.280168995914463e-15, 5.246026868069196e-15, 5.168749015385485e-15, 5.08418454879135e-15, 4.985064443442387e-15, 4.910467446959867e-15, 4.807871260066784e-15, 4.705244376043267e-15, 4.623690455350571e-15, 4.61118340943078e-15, 4.500864175277838e-15, 4.371722525008538e-15], [4.575728054368482e-15, 4.3175967692731e-15, 4.085399745424035e-15, 4.0525022770506036e-15, 4.3239051875371634e-15, 4.78368247928e-15, 5.087890728559474e-15, 5.310255797821593e-15, 5.37786703304826e-15, 5.424480924051807e-15, 5.3878663802856374e-15, 5.313013082186888e-15, 5.208948896338799e-15, 5.1452312986294575e-15, 5.122477164918111e-15, 5.15084358477078e-15, 5.191705145211764e-15, 5.244289936322587e-15, 5.274600440259989e-15, 5.301278225478701e-15, 5.285451848031734e-15, 5.2678787456546506e-15, 5.2299907533028355e-15, 5.1849910771117645e-15, 5.086743604679919e-15, 4.981857255117973e-15, 4.867106592307355e-15, 4.791456467312129e-15, 4.7135353630644956e-15, 4.626095362921345e-15, 4.566566166297646e-15, 4.550212451399216e-15, 4.441987497269781e-15, 4.3395028396711735e-15], [4.5650258339354234e-15, 4.326121509470491e-15, 4.099210638507299e-15, 4.030824010600031e-15, 4.330295089747345e-15, 4.695290517088467e-15, 4.9683703612296565e-15, 5.1619757207557535e-15, 5.231129761373014e-15, 5.275743429557921e-15, 5.248030744432842e-15, 5.1871399346365285e-15, 5.1082276561288515e-15, 5.069809771147214e-15, 5.069001138948107e-15, 5.109161503178815e-15, 5.153654503380782e-15, 5.203943199772041e-15, 5.229079850192955e-15, 5.248661698152031e-15, 5.228718615215165e-15, 5.210095008699343e-15, 5.166884499715097e-15, 5.106013099109775e-15, 4.9824026189626165e-15, 4.860160133895493e-15, 4.733733335443622e-15, 4.676980522257813e-15, 4.620441236504887e-15, 4.554879537083757e-15, 4.517984606863863e-15, 4.498073362533002e-15, 4.380472155751676e-15, 4.30655140873241e-15], [4.557930323857265e-15, 4.33847002847441e-15, 4.125069600838799e-15, 4.0345033592094144e-15, 4.352503764538024e-15, 4.6182602885023264e-15, 4.8572058138512874e-15, 5.011280638101392e-15, 5.074176112818819e-15, 5.111796407818274e-15, 5.093449442401104e-15, 5.0486342019731724e-15, 4.996237672153874e-15, 4.982183727738201e-15, 5.0004544579039116e-15, 5.049289691219776e-15, 5.09510514131294e-15, 5.140748843616186e-15, 5.162123658691183e-15, 5.176479251731068e-15, 5.156787105213116e-15, 5.1386862244543005e-15, 5.087419868777972e-15, 5.005756839837206e-15, 4.856031004219818e-15, 4.725562804977268e-15, 4.620567331458361e-15, 4.578689777959203e-15, 4.524738071193219e-15, 4.506582235220894e-15, 4.465908280417633e-15, 4.4337277411487716e-15, 4.31746525068341e-15, 4.2735432824149216e-15], [4.549993866411498e-15, 4.354906785374266e-15, 4.161183185941432e-15, 4.060295436221083e-15, 4.379190589975206e-15, 4.574278981833531e-15, 4.767739662805132e-15, 4.857823836893335e-15, 4.9070940944006975e-15, 4.9333347981671416e-15, 4.923896074356024e-15, 4.894970943531948e-15, 4.868496580882677e-15, 4.877111642267164e-15, 4.911526619790476e-15, 4.9663054601038355e-15, 5.0112751624755115e-15, 5.0513799039091076e-15, 5.0699850203451285e-15, 5.0825807086640835e-15, ...

# %% [markdown]
# The above interpolation is linear using a deluanay triangulation in lat, lon, z. You should probably be doing the interpolation in R-3 by converting from lat, lon, z, to x,y,z. This means the convex hull rule will provide interpolations all the way to the center of the earth.
#
# For time interpolation, you should probably use two time steps at a time?

# %% [markdown]
# # Fortran interpolator

# %% [markdown]
# look at  htint.F in in  /ccmcshare/MODELS_at_CCMC/TIEGCM/tgcmproc2.3_f90  and tgcmproc2.9_idl.

# %% [markdown]
# ### htint.F header
#
# ```fortran
#
# ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# c
# c Routines to do linear or log interpolation of gcm fields to
# c a linear height scale. Dimensions of fin, fht, and fout vary
# c depending on routine called.
# c
# c glbhtint() is global height interpolator:
# c   fin and fht (nlon,nzp,nlat) = global input and gcm heights fields
# c   fout(nlon,nlat,nhts) = global interpolated field returned
# c
# c glbhtin() is same as glbhtint except that the intput fields fin and fht
# c   are dimensioned (nlon,nlat,nzp) rather than (nlon,nzp,nlat). This is
# c   more convenient for some codes, e.g. "super_procs" gcm8proc, gcm9proc,
# c   etc.
# c
# c cuthtint() is height interpolator at some slice of the grid (e.g.,
# c   along a latitude (idim1 = imx) or longitude (idim1 = jmx)
# c   fin and fht (idim1,nzp) = input and gcm heights fields (at some cut)
# c   fout(idim1,nhts) = interpolated field returned
# c
# c intloc() interpolates fields at some location (lat,lon gcm grid point)
# c
# c Inputs common to all routines (dimensions vary):
# c
# c   fin: the gcm field at constant pressures
# c   fht: gcm heights at constant pressures
# c   hts: the height scale at which to do the interpolation
# c   nhts: number of heights in hts
# c   logint: if logint > 0, do log (exponential) interpolation,
# c           otherwise linear
# c   spval: if != 0., is special value returned in fout if
# c          ht(i) > max gcm height, or ht(i) < min gcm height.
# c          if = 0., extrapolation will be attempted if ht(i) out of range
# c   iprnt: print stuff out if > 0 (e.g., if spval is used)
# c
# c Outputs common to all routines (dimension of fout varies):
# c
# c   fout: returned field, interpolated to desired height scale
# c   ier: non-zero if an error has occurred
# c
# c Required routines:
# c   fminmax(), bracket()
# c
# c Ben Foster (ncar/hao)
# c foster@ncar.ucar.edu
# c 303-497-1595
# c
# ccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccccc
# c
# ```
# ### subroutine glbhtint
#
# ```fortran
# c
# c Do linear or log interpolation of fin to constant height surfaces
# c   in hts(nhts). Interpolated field returned in fout.
# c
# c On input:
# c   fin(nlon,nzp,nlat) = global input field
# c   fht(nlon,nzp,nlat) = global heights field
# c   nlon,nzp,nlat = dimensions of fin and fht
# c   hts(nhts) = heights at which to interpolate
# c   logint <= 0 -> do linear interpolation,
# c                  otherwise do exponential (log) interpolation
# c   spval: If spval is non-zero and hts(k) is not within fht range
# c          at the current grid point, then fout gets spval at the
# c          current grid point.
# c          If spval=0 and hts(k) is out of range, then
# c          fout will be extrapolated to hts(k)
# c   iprnt = 1 -> some error msgs will be printed if necessary
# c
# c On output:
# c   fout(nlon,nlat,nhts) = contains interpolated field
# c   ier = non-zero if an error has occurred
# c
# dimension fin(nlon,nzp,nlat),fht(nlon,nzp,nlat),
# +  fout(nlon,nlat,nhts),hts(nhts)
# dimension col(nzp)
# c
# do j=1,nlat
# do i=1,nlon
#           col(:) = fht(i,:,j)
#           call fminmax(col,nzp,htmin,htmax)
#           do k=1,nhts
#             if (hts(k).lt.htmin.or.hts(k).gt.htmax) then
#               if (spval.ne.0.) then
#                 fout(i,j,k) = spval
#                 goto 100
#               else
#                 k0 = nzp-1
#                 k1 = nzp
#               endif
#             else
#               call bracket(hts(k),col,nzp,1,k0,k1,ierr)
#               if (ierr.ne.0) then
#                 if (iprnt.gt.0) write(6,"('glbhtint: error from',
#      +            ' bracket: i j=',2i3,' k=',i3,' hts(k)=',f8.2,
#      +            ' hts col=',/(6f10.3))") i,j,k,hts(k),col
#                 fout(i,j,k) = spval
#                 goto 100
#               endif
#             endif
# c
# c Do linear or log interpolation:
# c
#             if (logint.gt.0) then
#               if (fin(i,k1,j).gt.0..and.fin(i,k1,j).ne.spval.and.
#      +            fin(i,k0,j).gt.0..and.fin(i,k0,j).ne.spval) then
#                 exparg = (alog(fin(i,k1,j) / fin(i,k0,j)) /
#      +                   (col(k1)-col(k0))) * (hts(k)-col(k0))
#                 fout(i,j,k) = fin(i,k0,j)*exp(exparg)
#               else
#                 fout(i,j,k) = spval
#               endif
#             else
#               f1 = (hts(k)-col(k0)) / (col(k1)-col(k0))
#               fout(i,j,k) = f1*fin(i,k1,j) + (1.-f1)*fin(i,k0,j)
#             endif
#  100        continue
#           enddo
#         enddo
#       enddo
#       return
#       end
# c
# ```

# %% [markdown]
# ### subroutine fminmax(f,n,rmin,rmax)
# ```fortran
# !
# ! Return min and max of array f(n), excluding any values == spval:
# !
#       use proc, only: spval
#       implicit none
#       integer, intent(in)  :: n
#       real,    intent(in)  :: f(n)
#       real,    intent(out) :: rmin,rmax
#       integer i
# !
# !     rmin = spval
# !     rmax = -spval
# !
# ! On dataproc with 4-byte reals, huge(x) = 0.34028235E+39
#       rmin = huge(rmin)
#       rmax = -rmin
#       do i=1,n
#         if (f(i).ne.spval.and.f(i).gt.rmax) rmax = f(i)
#         if (f(i).ne.spval.and.f(i).lt.rmin) rmin = f(i)
#       enddo
#       return
#       end subroutine fminmax
# ```

# %% [markdown]
# ### subroutine bracket(x,xx,nx,inc,n1,n2,ier)
# ```fortran
#       implicit none
# !
# ! Bracket x in xx(nx), returning lower index in n1 and upper index in n2
# ! If inc > 0 -> array increases from bottom to top,
# ! If inc <= 0 -> array increases from top to bottom
# !
#       integer,intent(in) :: nx,inc
#       integer,intent(out) :: n1,n2,ier
#       real,intent(in) :: x,xx(nx)
#       integer :: i
# !
# ! Array increases from bottom to top:
#       ier = 0
#       if (inc.gt.0) then
#         if (x.lt.xx(1)) then
#           n1 = 1
#           n2 = 2
#           ier = 1
#           return
#         endif
#         if (x.gt.xx(nx)) then
#           n1 = nx-1
#           n2 = nx
#           ier = 2
#           return
#         endif
#         do i=1,nx-1
#           if (x.ge.xx(i).and.x.le.xx(i+1)) then
#             n1 = i
#             n2 = i+1
#             return
#           endif
#         enddo
# !
# ! Array increases from top to bottom:
#       else
#         if (x.gt.xx(1)) then
#           n1 = 1
#           n2 = 2
#           ier = 3
#           return
#         endif
#         if (x.lt.xx(nx)) then
#           n1 = nx-1
#           n2 = nx
#           ier = 4
#           return
#         endif
#         do i=1,nx-1
#           if (x.le.xx(i).and.x.ge.xx(i+1)) then
#             n1 = i
#             n2 = i+1
#             return
#           endif
#         enddo
#       endif
#       return
#       end subroutine bracket
#
# ```

# %% [markdown]
# # Binding interpolator functions to C++
#
# http://pybind11.readthedocs.io/en/master/advanced/pycpp/object.html
#
# ## Compiling and importing a c++ module into python with cppimport
# https://github.com/tbenthompson/cppimport
#
# All the steps can be performed in python using the following
# ```python
# import cppimport
# somecode = cppimport.imp("somecode") #This will pause for a moment to compile the module
# somecode.square(9)
# 81
# ```
#
# ## Compiling with cmake
# CMakeLists.txt:
#
# ```cmake
# cmake_minimum_required(VERSION 2.8.12)
# project(example)
# set(PYBIND11_CPP_STANDARD -std=c++11)
# add_subdirectory(pybind11)
# pybind11_add_module(example example.cpp)
#
# ```
# Then compile with these steps
# ```console
# (sunpy):mkdir build
# (sunpy):cd build
# (sunpy):cmake .. -DPYBIND11_PYTHON_VERSION=2.7 -DCMAKE_CXX_COMPILER=clang -DCMAKE_C_COMPILER=clang -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=..
# (sunpy):make
# ```
# Then import from python
# ```python
# import example
# example.add(3,5)
# ```

# %%
import ccmc_interpolator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-8b09119d4477> in <module>()
# ----> 1 import ccmc_interpolator
#
# ImportError: No module named ccmc_interpolator

# %%
from collections import namedtuple

# %%
tiegcm = ccmc_interpolator.TIEGCM_cpp('sample_data/jasoon_shim_052317_IT_10/out/s001.nc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2359e1617c35> in <module>()
# ----> 1 tiegcm = ccmc_interpolator.TIEGCM_cpp('sample_data/jasoon_shim_052317_IT_10/out/s001.nc')
#
# NameError: name 'ccmc_interpolator' is not defined

# %%
tiegcm.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-d710b3a995ae> in <module>()
# ----> 1 tiegcm.name
#
# NameError: name 'tiegcm' is not defined

# %%
z_test = 39005780.

# %%
Point3D = namedtuple("Point3D", ['height', 'latitude','longitude'])
Point4D = namedtuple("Point4D", ['height','latitude','longitude', 'time'])

# %%
point = Point4D(z_test,  87.,  170., 3.5 )

# %%
tiegcm.interpolate('NE', *point)
# Out:
# 280229.90625

# %%
result
# Out:
# 280229.90647651337

# %% [markdown]
# # Interpolation at the poles
#
# Currently this results in a qhull error. Apparently, there are no cells that reach the poles. We will fill these using Lutz's algorithm.
#
#     ; at-pole boundary conditions
#     for iq=0,n_q-1 do begin
#     ; pole_bc=0: zero value
#         if pole_bc[iq] eq 0 then begin
#             fields[iq,*,0,*]=0.
#             fields[iq,*,ny_blk-1,*]=0.
#         endif
#     ; pole_bc=1: average value that Masha mentioned
#         if pole_bc[iq] eq 1 then begin
#             for iz=0,nz_blk-1 do begin
#                 fields[iq,*,0,iz]=total(fields[iq,0:nx_blk-2,1,iz])/(nx_blk-1)
#                 fields[iq,*,ny_blk-1,iz]=total(fields[iq,0:nx-2,ny_blk-2,iz])/(nx_blk-1)
#             endfor
#         endif
#     ; pole_bc=2: no-derivative
#         if pole_bc[iq] eq 2 then begin
#                 fields[iq,*,0,*]       =fields[iq,*,1,*]
#                 fields[iq,*,ny_blk-1,*]=fields[iq,*,ny_blk-2,*]
#         endif
#     endfor

# %% [markdown]
# Variable polar boundary coditions
#
#     Variable          pole_bc
#     T_n       1
#     Vn_Lon       2
#     Vn_Lat       2
#     rho(O)       1
#     rho(NO)       1
#     rho(N4S)       1
#     HE       1
#     N_e       1
#     T_e       1
#     T_i       1
#     TEC       1
#     rho(O2)       1
#     O2P_ELD       1
#     Omega       1
#     PHI       1
#     Vi_Lon       2
#     Vi_Lat       2
#     Vi_IP       1
#     N(O+)       1
#     N(N2+)       1
#     N(N+)       1
#     N(NO+)       1
#     SIGMA_PED       1
#     SIGMA_HAL       1
#     DEN       1
#     QJOULE       1
#     Z       1
#     ZG       1
#     O_N2       1
#     QJOULE_INTEG       1
#     EFLUX       1
#     HMF2       1
#     NMF2       1
#     N2D_ELD       1
#     O2N       1
#     N2N       1
#     T_lbc       1
#     Vlbc_Lon       2
#     Vlbc_Lat       2
#     TN_lbc       1
#     VN,lbc_Lon       2
#     VN,lbc_Lat       2

# %%
import pandas as pd

# %%
import numpy as np

# %%
from tiegcm import TIEGCM, Point3D, Point4D, Slice_key4D, ColumnSlice4D, ColumnSlice3D

# %%
from util import average_longitude

# %%
from tiegcm import TIEGCM

test_file = "sample_data/jasoon_shim_052317_IT_10/out/s001.nc"
tiegcm = TIEGCM(test_file)

# %%
from scipy.spatial import kdtree

from scipy.interpolate import LinearNDInterpolator
time = 3.5

# %%
z_max = tiegcm.z.max()
z_test = 1.1*z_max
p4 = Point4D(time, z_test, 20.5, .5)

column_slicer = tiegcm.get_column_slicer_4D(p4)
z_column, lat_column, lon_column = tiegcm.get_3D_column(column_slicer)

time_index = column_slicer.time.start

# %%
z = tiegcm.z[time_index, -1, :, :]
lat = tiegcm.lat_[-1]
lon = tiegcm.lon_[-1]

outer_points = np.array(zip(z.ravel()/z.max(), lat.ravel(), lon.ravel()))

tree = scipy.spatial.KDTree(outer_points)

z_test = 1.1*tiegcm.z[time_index, -1, :, :].max() # high altitude test

p4 = Point4D(time, z_test, 20.5, .5)
p = Point3D(*p4[1:])

distances, vertices = tree.query(p, p = 1, k = 3)

coord_indices = np.array(zip(*np.unravel_index(vertices, z.shape)))

lat_indices, lon_indices = coord_indices[:,0], coord_indices[:,1]

lnd_lat = LinearNDInterpolator(tree.data[vertices][:,1:], tiegcm.lat_[-1][lat_indices, lon_indices])
lnd_lon = LinearNDInterpolator(tree.data[vertices][:,1:], tiegcm.lon_[-1][lat_indices, lon_indices])
lnd_z = LinearNDInterpolator(tree.data[vertices][:,1:], tiegcm.z[time_index,-1, lat_indices, lon_indices])
assert (float(lnd_lat(p[1:])) == p.latitude)
assert (float(lnd_lon(p[1:])) == p.longitude)

# %%
zz_top = z_column[:,-1,:,:]

# %%
assert zz_top.min() <= lnd_z(p[1:]) <= zz_top.max()

# %% [markdown]
# compare with column

# %%
pd.Series(column_slicer._asdict()).to_frame().T
# Out:
#                  time                   height             latitude  \
# 0  slice(9, 11, None)  slice(None, None, None)  slice(22, 24, None)
#
#              longitude
# 0  slice(36, 38, None)

# %%
tiegcm.z[time_index,-1,lat_indices, lon_indices]
# Out:
# array([ 63661320.,  64271104.,  63822360.], dtype=float32)

# %%
tiegcm.z[time_index,-1,:,:].min(), tiegcm.z[time_index,-1,:,:].max()
# Out:
# (58778880.0, 71708504.0)

# %%
tree.data[vertices][:,1:]
# Out:
# array([[ 22.5,   0. ],
#        [ 17.5,   0. ],
#        [ 22.5,   5. ]])

# %%
z_column.shape, lat_column.shape, lon_column.shape
# Out:
# ((2, 29, 2, 2), (29, 2, 2), (29, 2, 2))

# %%
lat_column[-1], lon_column[-1]
# Out:
# (array([[ 17.5,  17.5],
#         [ 22.5,  22.5]]), array([[ 0.,  5.],
#         [ 0.,  5.]]))

# %%
tiegcm.z[time_index, -1, :, :].max()
# Out:
# 71708504.0

# %%
height_index = -1

norm = tiegcm.z[time_index, height_index, :, :].max()

# %%
data = [go.Surface( z=tiegcm.z[time_index, height_index, :, :]/norm,
                    x=tiegcm.lon,
                    y=tiegcm.lat,
                    opacity = .9,
                   name = 'max_height'
                    ),
        go.Surface( z=z_column[0, height_index, :, :]/norm,
                    x=lon_column[height_index],
                    y = lat_column[height_index],
                    opacity = 1,
                   name = 'column_height',
                    ),
        go.Scatter3d(x = [p.longitude], y =[ p.latitude],z = [p.height/norm], name = 'query', mode = 'markers'),
        go.Scatter3d(x = [lon[c[0], c[1]] for c in coord_indices], 
                     y = [lat[c[0], c[1]] for c in coord_indices], 
                     z = tiegcm.z[time_index,height_index, lat_indices, lon_indices]/norm, mode = 'markers')
]

iplot(data)
# Out:
# <div id="7660734f-b8f3-4e21-9460-48d22913a720" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7660734f-b8f3-4e21-9460-48d22913a720", [{"opacity": 0.9, "name": "max_height", "y": [-90.0, -87.5, -82.5, -77.5, -72.5, -67.5, -62.5, -57.5, -52.5, -47.5, -42.5, -37.5, -32.5, -27.5, -22.5, -17.5, -12.5, -7.5, -2.5, 2.5, 7.5, 12.5, 17.5, 22.5, 27.5, 32.5, 37.5, 42.5, 47.5, 52.5, 57.5, 62.5, 67.5, 72.5, 77.5, 82.5, 87.5, 90.0], "x": [-180.0, -175.0, -170.0, -165.0, -160.0, -155.0, -150.0, -145.0, -140.0, -135.0, -130.0, -125.0, -120.0, -115.0, -110.0, -105.0, -100.0, -95.0, -90.0, -85.0, -80.0, -75.0, -70.0, -65.0, -60.0, -55.0, -50.0, -45.0, -40.0, -35.0, -30.0, -25.0, -20.0, -15.0, -10.0, -5.0, 0.0, 5.0, 10.0, 15.0, 20.0, 25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0, 90.0, 95.0, 100.0, 105.0, 110.0, 115.0, 120.0, 125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 155.0, 160.0, 165.0, 170.0, 175.0, 180.0], "z": [[0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605, 0.9365763664245605], [0.95817631483078, 0.9568725228309631, 0.9554116129875183, 0.9538052082061768, 0.9520659446716309, 0.950207531452179, 0.9482446908950806, 0.9461928009986877, 0.9440682530403137, 0.941887617111206, 0.9396679401397705, 0.9374268054962158, 0.9351814389228821, 0.9329494833946228, 0.9307480454444885, 0.9285941123962402, 0.9265042543411255, 0.9244940876960754, 0.9225789904594421, 0.9207733273506165, 0.9190905094146729, 0.9175428748130798, 0.9161418676376343, 0.914897620677948, 0.9138190746307373, 0.9129139184951782, 0.9121884107589722, 0.911647617816925, 0.9112950563430786, 0.9111328721046448, 0.9111620783805847, 0.9113819003105164, 0.9117905497550964, 0.9123847484588623, 0.9131597280502319, 0.9141098260879517, 0.9152277708053589, 0.9165053963661194, 0.9179331660270691, 0.9195007085800171, 0.9211964011192322, 0.9230079054832458, 0.924921989440918, 0.9269245862960815, 0.9290010333061218, 0.9311361312866211, 0.9333140850067139, 0.9355188012123108, 0.9377338886260986, 0.9399429559707642, 0.942129373550415, 0.9442766308784485, 0.946368396282196, 0.9483890533447266, 0.9503226280212402, 0.9521546363830566, 0.9538705945014954, 0.9554570913314819, 0.9569016098976135, 0.958192765712738, 0.959320068359375, 0.9602745175361633, 0.9610480666160583, 0.9616345763206482, 0.9620288014411926, 0.9622274041175842, 0.9622284173965454, 0.9620314836502075, 0.9616379141807556, 0.9610504508018494, 0.960273385047912 ...

# %%
p, time
# Out:
# (Point3D(height=78879354.400000006, latitude=20.5, longitude=0.5), 3.5)

# %%
tiegcm.time_interpolate_high_altitude(p, 'Z', time)
# Out:
# 63921337.6

# %% [markdown]
# # Scale height
#
# Scale height given by
#
# $H(h) = KT_{top}/M_xg(h)$
#
# $g(h) = g_0(r_e/(r_e+h))^2$
#
# $g_0 = ?$

# %%
p
# Out:
# Point3D(height=78879354.400000006, latitude=20.5, longitude=0.5)

# %%
def scale_height(self, p, time, variable):
    print variable
    T = self.time_interpolate_high_altitude(p, 'TN', time)
    return T
scale_height(tiegcm, p, time, 'O2')
# Out:
# O2
# 9.999999616903162e+35

# %%
tn = tiegcm.rootgrp.variables['TN']

# %%
tn.__array__().max()
# Out:
# 9.9999996e+35

# %% [markdown]
# ## Interpolator Call Graph

# %% [markdown]
# ### time_interpolate(point, time)
# * retrieves slice_key corresponding to point,time
# * scales height down using self.z_scale
# * wraps longitude into valid range
# * calls `time_interpolators[slice_key](p, time)`
#
# ### self.time_interpolators[slice_key]
# * a subclass of defaultdict
# * if slice_key is not found: calls self.create_3Dtime_interpolator(slice_key)
# * stores result

# %% [markdown]
# slice_key is a 4D slice that looks like this

# %%
pd.Series(dict(time = (slice, (8,11, None)), 
               height = (slice, (None, None, None)),
               latitude = (slice, (35, 37, None)),
               longitude = (slice, (65, 67, None)),
               variable = 'Z'
              )).to_frame().T
# Out:
#                                  height                          latitude  \
# 0  (<type 'slice'>, (None, None, None))  (<type 'slice'>, (35, 37, None))
#
#                           longitude                             time variable
# 0  (<type 'slice'>, (65, 67, None))  (<type 'slice'>, (8, 11, None))        Z

# %% [markdown]
# ### create_3Dtime_interpolator
# * takes a 4d slice key and returns a TimeInterpolator object
# * constructs two 3D interpolators corresponding to two time steps: calls self.get_3D_interpolator(slice_key, i) i $\in$ [0,1]
# * returns a TimeInterpolator(interpolators)
#
# ### get_3D_interpolator(slice_key, i = 0)
# * retrieves spatial data corresponding to time slice
# * z_column, lat_column, lon_column, i
#
# ### get_delaunay_3D
# * scales the z_column by self.z_scale
# * martials the vertices into points
# * creates an instance of Delaunay(points)

# %% [markdown]
# ## Cartesian interpolation
#
# We need to convert the positions from spherical to cartesian in two place:
# * time_interpolate
# * get_delaunay_3D
#
# We may also need the inverse transformation for testing

# %%
from collections import namedtuple

# %%
Point3DCartesian = namedtuple("Point3DCartesian", ['x','y','z'])
Point3DSpherical = namedtuple("Point3DSpherical", ['r','theta','phi'])

# %%
from tiegcm import geo_to_spherical, spherical_to_cartesian, geo_to_cartesian

# %%
geo_to_cartesian(Point3D(0, 90, 0))
# Out:
# Point3DCartesian(x=-0.0, y=0.0, z=637100800.0)

# %% [markdown]
# for $ r \in [0, \inf), \theta \in [0, \pi], \phi \in [0, 2\pi) $
# $$ x = r sin \theta cos \phi $$
#
# $$ y = r sin \theta sin \phi $$
#
# $$ z = r cos \theta $$

# %%
print 'lat in', tiegcm.lat.min(), tiegcm.lat.max()
print 'lon in', tiegcm.lon.min(), tiegcm.lon.max()
# Out:
# lat in -87.5 87.5
# lon in -180.0 180.0

# %%
npoints = 10
h = np.linspace(0, 5, npoints)
lat = np.linspace(-25, 90, npoints)
lon = np.linspace(-30, 30, npoints)
geo = Point3D(h,lat,lon)

# %%
pd.concat([pd.DataFrame.from_dict(geo._asdict()),
           pd.DataFrame.from_dict(geo_to_spherical(geo)._asdict()),
           pd.DataFrame.from_dict(geo_to_cartesian(geo)._asdict()),], axis = 1)
# Out:
#      height   latitude  longitude             r     theta       phi  \
# 0  0.000000 -25.000000 -30.000000  6.371008e+08  2.007129  2.617994
# 1  0.555556 -12.222222 -23.333333  6.371008e+08  1.784114  2.734349
# 2  1.111111   0.555556 -16.666667  6.371008e+08  1.561100  2.850704
# 3  1.666667  13.333333 -10.000000  6.371008e+08  1.338086  2.967060
# 4  2.222222  26.111111  -3.333333  6.371008e+08  1.115071  3.083415
# 5  2.777778  38.888889   3.333333  6.371008e+08  0.892057  3.199770
# 6  3.333333  51.666667  10.000000  6.371008e+08  0.669043  3.316126
# 7  3.888889  64.444444  16.666667  6.371008e+08  0.446029  3.432481
# 8  4.444444  77.222222  23.333333  6.371008e+08  0.223014  3.548836
# 9  5.000000  90.000000  30.000000  6.371008e+08  0.000000  3.665191
#
#               x             y             z
# 0 -5.000512e+08  2.887047e+08 -2.692504e+08
# 1 -5.717366e+08  2.466231e+08 -1.348767e+08
# 2 -6.103072e+08  1.827140e+08  6.177407e+06
# 3 -6.105096e+08  1.076493e+08  1.469256e+08
# 4 -5.711119e+08  3.326348e+07  2.803965e+08
# 5 -4.950579e+08 -2.883384e+07  3.999796e+08
# 6 -3.891493e+08 -6.861752e+07  4.997519e+08
# 7 -2.632904e+08 -7.882397e+07  5.747716e+08
# 8 -1.293838e+08 -5.581071e+07  6.213231e+08
# 9 -0.000000e+00 -0.000000e+00  6.371008e+08

# %% [markdown]
# # Wrap error

# %%
from tiegcm.tiegcm import TIEGCM
import numpy.ma as ma
from util import boundary_conditions

test_file = "sample_data/jasoon_shim_052317_IT_10/out/s001.nc"
tiegcm = TIEGCM(test_file)

# %%
ne = tiegcm.rootgrp.variables['NE'].__array__()

# %%
tn = tiegcm.rootgrp.variables['TN'].__array__()

# %%
if tn[:,-1,:,:].mask.all():
    tn[:,-1,:,:] = tn[:,-2,:,:].data

# %%
tn.filled(np.nan)
# Out:
# array([[[[  170.08384705,   170.10655212,   170.12921143, ...,
#             170.01724243,   170.03903198,   170.06129456],
#          [  170.04312134,   170.08796692,   170.1399231 , ...,
#             169.95968628,   169.97840881,   170.00636292],
#          [  170.3600769 ,   170.46284485,   170.55561829, ...,
#             170.04898071,   170.14712524,   170.25285339],
#          ...,
#          [  169.43707275,   169.43159485,   169.4262085 , ...,
#             169.45088196,   169.44677734,   169.44219971],
#          [  169.46318054,   169.45567322,   169.4513092 , ...,
#             169.50343323,   169.48721313,   169.47373962],
#          [  169.51539612,   169.51118469,   169.50836182, ...,
#             169.53608704,   169.52789307,   169.52098083]],
#
#         [[  164.30395508,   164.40379333,   164.50543213, ...,
#             164.02267456,   164.11265564,   164.20664978],
#          [  164.02935791,   164.3782959 ,   164.74520874, ...,
#             163.1592865 ,   163.41372681,   163.7056427 ],
#          [  165.14089966,   165.76602173,   166.334198  , ...,
#             163.19477844,   163.82609558,   164.48472595],
#          ...,
#          [  159.63223267,   159.55470276,   159.48202515, ...,
#             159.88398743,   159.79673767,   159.71305847],
#          [  159.0229187 ,   158.92480469,   158.84945679, ...,
#             159.44152832,   159.28283691,   159.14273071],
#          [  159.54322815,   159.50801086,   159.47952271, ...,
#             159.68634033,   159.63273621,   159.5848999 ]],
#
#         [[  183.4334259 ,   183.70614624,   183.97773743, ...,
#             182.62924194,   182.89291382,   183.16166687],
#          [  183.37385559,   184.48773193,   185.59101868, ...,
#             180.19902039,   181.20709229,   182.27267456],
#          [  184.85165405,   186.72756958,   188.34680176, ...,
#             178.48626709,   180.64048767,   182.79370117],
#          ...,
#          [  166.48516846,   166.37358093,   166.28126526, ...,
#             166.90293884,   166.75048828,   166.61146545],
#          [  163.95054626,   163.8036499 ,   163.72396851, ...,
#             164.7684021 ,   164.43647766,   164.16252136],
#          [  165.91824341,   165.88722229,   165.87513733, ...,
#             166.1217804 ,   166.03596497,   165.96794128]],
#
#         ...,
#         [[ 1186.06750488,  1185.22058105,  1184.30102539, ...,
#            1188.11181641,  1187.51867676,  1186.83557129],
#          [ 1181.10217285,  1178.5670166 ,  1175.74853516, ...,
#            1186.53540039,  1185.12609863,  1183.30322266],
#          [ 1159.84484863,  1158.53356934,  1157.35229492, ...,
#            1165.11669922,  1163.12084961,  1161.36181641],
#          ...,
#          [ 1139.11291504,  1141.05688477,  1142.81005859, ...,
#            1134.27331543,  1135.52844238,  1137.20092773],
#          [ 1114.93811035,  1115.33984375,  1115.69604492, ...,
#            1113.78369141,  1114.1295166 ,  1114.52404785],
#          [ 1097.58532715,  1096.44189453,  1095.34313965, ...,
#            1101.19555664,  1099.97119141,  1098.76477051]],
#
#         [[ 1186.05847168,  1185.21203613,  1184.29309082, ...,
#            1188.10144043,  1187.50866699,  1186.8260498 ],
#          [ 1181.09802246,  1178.56420898,  1175.74707031, ...,
#            1186.52832031,  1185.11987305,  1183.29797363],
#          [ 1159.86071777,  1158.55029297,  1157.37011719, ...,
#            1165.12939453,  1163.13464355,  1161.37658691],
#          ...,
#          [ 1139.09997559,  1141.04394531,  1142.79724121, ...,
#            1134.25805664,  1135.5144043 ,  1137.1875    ],
#          [ 1114.98669434,  1115.38842773,  1115.74450684, ...,
#            1113.83276367,  1114.1784668 ,  1114.57287598],
#          [ 1097.6439209 ,  1096.50061035,  1095.40185547, ...,
#            1101.25268555,  1100.02893066,  1098.82299805]],
#
#         [[           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          ...,
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan]]],
#
#
#        [[[  170.13650513,   170.16299438,   170.18951416, ...,
#             170.05914307,   170.0843811 ,   170.11022949],
#          [  170.14552307,   170.20240784,   170.26455688, ...,
#             170.01722717,   170.05206299,   170.09507751],
#          [  170.51605225,   170.64671326,   170.76571655, ...,
#             170.11671448,   170.24452209,   170.37982178],
#          ...,
#          [  169.38937378,   169.381073  ,   169.37298584, ...,
#             169.40757751,   169.40313721,   169.39694214],
#          [  169.39938354,   169.39822388,   169.40036011, ...,
#             169.42185974,   169.41131592,   169.40377808],
#          [  169.51921082,   169.51661682,   169.51551819, ...,
#             169.53561401,   169.5287323 ,   169.52325439]],
#
#         [[  164.47924805,   164.59622192,   164.71522522, ...,
#             164.14920044,   164.25486755,   164.36517334],
#          [  164.56820679,   164.95039368,   165.34092712, ...,
#             163.54586792,   163.85905457,   164.20204163],
#          [  165.91664124,   166.63885498,   167.29444885, ...,
#             163.64199829,   164.38700867,   165.1558075 ],
#          ...,
#          [  159.42134094,   159.33909607,   159.26081848, ...,
#             159.66548157,   159.5859375 ,   159.50430298],
#          [  158.71234131,   158.64466858,   158.60090637, ...,
#             159.05041504,   158.91639709,   158.80325317],
#          [  159.5307312 ,   159.50065613,   159.4777832 , ...,
#             159.66163635,   159.61152649,   159.56777954]],
#
#         [[  184.14875793,   184.47592163,   184.8012085 , ...,
#             183.18093872,   183.49879456,   183.82221985],
#          [  185.55683899,   186.71841431,   187.83576965, ...,
#             182.03817749,   183.19328308,   184.37397766],
#          [  187.72514343,   189.80632019,   191.5892334 , ...,
#             180.53421021,   182.99386597,   185.42393494],
#          ...,
#          [  165.97013855,   165.86195374,   165.7677002 , ...,
#             166.31362915,   166.1993866 ,   166.08428955],
#          [  163.14445496,   163.081604  ,   163.08969116, ...,
#             163.74490356,   163.47853088,   163.27740479],
#          [  165.90887451,   165.89147949,   165.89422607, ...,
#             166.07974243,   166.00335693,   165.94625854]],
#
#         ...,
#         [[ 1166.71569824,  1166.83740234,  1166.87780762, ...,
#            1165.87414551,  1166.23217773,  1166.51342773],
#          [ 1160.6940918 ,  1159.31799316,  1157.80163574, ...,
#            1163.6652832 ,  1162.89562988,  1161.89660645],
#          [ 1145.80834961,  1144.87231445,  1144.28771973, ...,
#            1151.12060547,  1148.93774414,  1147.1574707 ],
#          ...,
#          [ 1110.61621094,  1117.94616699,  1125.50585938, ...,
#            1093.5546875 ,  1098.11157227,  1103.89196777],
#          [ 1095.41870117,  1098.20849609,  1101.15881348, ...,
#            1088.62963867,  1090.57629395,  1092.85534668],
#          [ 1082.30383301,  1082.59411621,  1082.92553711, ...,
#            1081.70141602,  1081.85583496,  1082.05712891]],
#
#         [[ 1166.70544434,  1166.828125  ,  1166.86950684, ...,
#            1165.86157227,  1166.22033691,  1166.50231934],
#          [ 1160.6973877 ,  1159.32128906,  1157.80517578, ...,
#            1163.66821289,  1162.89868164,  1161.89978027],
#          [ 1145.8157959 ,  1144.87854004,  1144.29309082, ...,
#            1151.13232422,  1148.94812012,  1147.16638184],
#          ...,
#          [ 1110.66271973,  1117.98791504,  1125.54223633, ...,
#            1093.61035156,  1098.16540527,  1103.94262695],
#          [ 1095.47131348,  1098.2611084 ,  1101.21118164, ...,
#            1088.68200684,  1090.62878418,  1092.90795898],
#          [ 1082.37548828,  1082.66503906,  1082.99560547, ...,
#            1081.77355957,  1081.92810059,  1082.12927246]],
#
#         [[           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          ...,
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan]]],
#
#
#        [[[  170.19300842,   170.21612549,   170.23937988, ...,
#             170.12626648,   170.14790344,   170.17021179],
#          [  170.18177795,   170.24607849,   170.31471252, ...,
#             170.0271759 ,   170.07130432,   170.12313843],
#          [  170.55201721,   170.70495605,   170.84863281, ...,
#             170.10220337,   170.2441864 ,   170.39624023],
#          ...,
#          [  169.34945679,   169.34347534,   169.33827209, ...,
#             169.36328125,   169.36004639,   169.35525513],
#          [  169.33239746,   169.33403015,   169.33869934, ...,
#             169.34431458,   169.33769226,   169.33366394],
#          [  169.45829773,   169.45922852,   169.46168518, ...,
#             169.46452332,   169.46095276,   169.4588623 ]],
#
#         [[  164.66366577,   164.76873779,   164.87643433, ...,
#             164.37208557,   164.46458435,   164.56202698],
#          [  164.80636597,   165.20170593,   165.60029602, ...,
#             163.71395874,   164.05540466,   164.42182922],
#          [  166.19396973,   166.99159241,   167.73013306, ...,
#             163.7442627 ,   164.53945923,   165.36633301],
#          ...,
#          [  159.24514771,   159.1784668 ,   159.11645508, ...,
#             159.44514465,   159.38027954,   159.3132019 ],
#          [  158.38365173,   158.3326416 ,   158.30474854, ...,
#             158.66705322,   158.55201721,   158.45710754],
#          [  159.25723267,   159.23880005,   159.22789001, ...,
#             159.35592651,   159.31600952,   159.28303528]],
#
#         [[  184.79727173,   185.09437561,   185.39060974, ...,
#             183.92337036,   184.20953369,   184.50158691],
#          [  186.70085144,   187.85810852,   188.95381165, ...,
#             183.07868958,   184.2883606 ,   185.50343323],
#          [  189.04011536,   191.27572632,   193.22541809, ...,
#             181.46166992,   184.03985596,   186.59809875],
#          ...,
#          [  165.56765747,   165.52600098,   165.49635315, ...,
#             165.71118164,   165.66304016,   165.61471558],
#          [  162.27844238,   162.25880432,   162.3082428 , ...,
#             162.74064636,   162.52151489,   162.36656189],
#          [  165.15646362,   165.16572571,   165.19602966, ...,
#             165.25479126,   165.20117188,   165.16830444]],
#
#         ...,
#         [[ 1153.68945312,  1154.24987793,  1154.73242188, ...,
#            1151.58630371,  1152.35253906,  1153.05541992],
#          [ 1149.0090332 ,  1148.46350098,  1147.91845703, ...,
#            1150.4041748 ,  1150.00524902,  1149.53137207],
#          [ 1154.2689209 ,  1155.19433594,  1156.07592773, ...,
#            1152.52087402,  1152.82995605,  1153.44128418],
#          ...,
#          [ 1094.20129395,  1102.51916504,  1110.83825684, ...,
#            1072.87207031,  1079.04211426,  1086.25732422],
#          [ 1097.82702637,  1100.88476562,  1104.0333252 , ...,
#            1089.7220459 ,  1092.19909668,  1094.91516113],
#          [ 1080.11999512,  1081.0859375 ,  1082.11462402, ...,
#            1077.66955566,  1078.40527344,  1079.22412109]],
#
#         [[ 1153.67724609,  1154.23815918,  1154.72119141, ...,
#            1151.57299805,  1152.33959961,  1153.04284668],
#          [ 1149.01025391,  1148.4642334 ,  1147.91882324, ...,
#            1150.40637207,  1150.00708008,  1149.53308105],
#          [ 1154.26293945,  1155.18676758,  1156.06762695, ...,
#            1152.52185059,  1152.82836914,  1153.43737793],
#          ...,
#          [ 1094.21960449,  1102.53515625,  1110.85205078, ...,
#            1072.89465332,  1079.06384277,  1086.27746582],
#          [ 1097.83764648,  1100.89624023,  1104.0456543 , ...,
#            1089.73095703,  1092.20837402,  1094.92504883],
#          [ 1080.17407227,  1081.13916016,  1082.16687012, ...,
#            1077.72412109,  1078.45996094,  1079.27868652]],
#
#         [[           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          ...,
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan]]],
#
#
#        ...,
#        [[[  170.8787384 ,   170.89001465,   170.9012146 , ...,
#             170.84538269,   170.8563385 ,   170.86749268],
#          [  170.72010803,   170.78118896,   170.83190918, ...,
#             170.48643494,   170.57124329,   170.64967346],
#          [  170.69592285,   170.78077698,   170.83113098, ...,
#             170.26577759,   170.43348694,   170.57879639],
#          ...,
#          [  169.57313538,   169.63160706,   169.67959595, ...,
#             169.37295532,   169.43966675,   169.50779724],
#          [  169.46502686,   169.45391846,   169.43984985, ...,
#             169.47767639,   169.47703552,   169.47279358],
#          [  169.32366943,   169.32537842,   169.32855225, ...,
#             169.32736206,   169.32466125,   169.32342529]],
#
#         [[  166.21743774,   166.36523438,   166.51779175, ...,
#             165.81350708,   165.94052124,   166.07550049],
#          [  164.49679565,   164.95188904,   165.39550781, ...,
#             163.12289429,   163.57572937,   164.03596497],
#          [  164.55397034,   165.14099121,   165.62223816, ...,
#             162.27331543,   163.10214233,   163.86938477],
#          ...,
#          [  159.77883911,   159.96520996,   160.11039734, ...,
#             159.11395264,   159.33796692,   159.56474304],
#          [  158.47433472,   158.41183472,   158.33468628, ...,
#             158.5604248 ,   158.5491333 ,   158.52041626],
#          [  157.56997681,   157.56674194,   157.5708313 , ...,
#             157.62309265,   157.59825134,   157.58050537]],
#
#         [[  181.58232117,   182.02778625,   182.48806763, ...,
#             180.36808777,   180.74931335,   181.15509033],
#          [  177.81622314,   179.22871399,   180.64102173, ...,
#             173.7638855 ,   175.06486511,   176.42198181],
#          [  180.15371704,   182.11315918,   183.8563385 , ...,
#             173.29705811,   175.70155334,   178.00375366],
#          ...,
#          [  169.43147278,   170.07643127,   170.61894226, ...,
#             167.24977112,   167.9800415 ,   168.71992493],
#          [  165.59797668,   165.56607056,   165.47348022, ...,
#             165.31567383,   165.47183228,   165.56663513],
#          [  161.25784302,   161.27127075,   161.29646301, ...,
#             161.2888031 ,   161.26664734,   161.25630188]],
#
#         ...,
#         [[ 1368.38244629,  1368.56665039,  1368.78564453, ...,
#            1368.05029297,  1368.12329102,  1368.23425293],
#          [ 1309.7956543 ,  1308.27075195,  1307.2623291 , ...,
#            1317.07434082,  1314.24853516,  1311.8034668 ],
#          [ 1216.32336426,  1210.92016602,  1207.72387695, ...,
#            1243.5078125 ,  1232.9354248 ,  1223.75402832],
#          ...,
#          [ 1063.78015137,  1056.36865234,  1049.70666504, ...,
#            1085.47949219,  1078.80737305,  1071.42553711],
#          [ 1066.22155762,  1065.56628418,  1065.62207031, ...,
#            1072.32507324,  1069.63427734,  1067.58532715],
#          [ 1112.37341309,  1113.40283203,  1114.32556152, ...,
#            1108.7277832 ,  1110.02697754,  1111.24536133]],
#
#         [[ 1368.41699219,  1368.60180664,  1368.82128906, ...,
#            1368.08288574,  1368.15649414,  1368.26818848],
#          [ 1309.81933594,  1308.29467773,  1307.28686523, ...,
#            1317.09802246,  1314.2722168 ,  1311.82702637],
#          [ 1216.32495117,  1210.92456055,  1207.73242188, ...,
#            1243.50817871,  1232.93505859,  1223.75415039],
#          ...,
#          [ 1063.7923584 ,  1056.38012695,  1049.71728516, ...,
#            1085.49194336,  1078.82019043,  1071.43823242],
#          [ 1066.25756836,  1065.60400391,  1065.66125488, ...,
#            1072.35388184,  1069.66577148,  1067.6192627 ],
#          [ 1112.37036133,  1113.39782715,  1114.31884766, ...,
#            1108.73083496,  1110.0279541 ,  1111.24414062]],
#
#         [[           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          ...,
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan]]],
#
#
#        [[[  170.89741516,   170.89927673,   170.90055847, ...,
#             170.88850403,   170.89199829,   170.89497375],
#          [  170.7381134 ,   170.77090454,   170.7953186 , ...,
#             170.59552002,   170.64953613,   170.69740295],
#          [  170.69709778,   170.78309631,   170.83651733, ...,
#             170.28465271,   170.44210815,   170.58175659],
#          ...,
#          [  169.69984436,   169.74713135,   169.78044128, ...,
#             169.50735474,   169.57594299,   169.64154053],
#          [  169.55084229,   169.53182983,   169.51087952, ...,
#             169.58953857,   169.58021545,   169.56716919],
#          [  169.45329285,   169.45880127,   169.4657135 , ...,
#             169.44541931,   169.44656372,   169.44920349]],
#
#         [[  166.38897705,   166.50801086,   166.63002014, ...,
#             166.05862427,   166.16342163,   166.27381897],
#          [  164.59515381,   164.98068237,   165.36148071, ...,
#             163.45874023,   163.82899475,   164.20956421],
#          [  164.58256531,   165.19187927,   165.70004272, ...,
#             162.29801941,   163.11445618,   163.88397217],
#          ...,
#          [  160.26272583,   160.41346741,   160.5111084 , ...,
#             159.61923218,   159.8506012 ,   160.07037354],
#          [  158.86714172,   158.77510071,   158.67149353, ...,
#             159.04585266,   159.0045166 ,   158.94442749],
#          [  158.07923889,   158.09022522,   158.10821533, ...,
#             158.08892822,   158.07858276,   158.0753479 ]],
#
#         [[  182.0395813 ,   182.43719482,   182.84649658, ...,
#             180.94651794,   181.29139709,   181.65667725],
#          [  178.03808594,   179.34474182,   180.66326904, ...,
#             174.362854  ,   175.52990723,   176.76068115],
#          [  180.32365417,   182.31059265,   184.08624268, ...,
#             173.47317505,   175.85531616,   178.15719604],
#          ...,
#          [  170.8271637 ,   171.40148926,   171.85427856, ...,
#             168.7104187 ,   169.44476318,   170.16291809],
#          [  167.01237488,   166.92085266,   166.77325439, ...,
#             166.9067688 ,   167.00746155,   167.04234314],
#          [  162.75123596,   162.79302979,   162.84490967, ...,
#             162.68908691,   162.69906616,   162.71983337]],
#
#         ...,
#         [[ 1379.52697754,  1379.73217773,  1379.92871094, ...,
#            1378.875     ,  1379.09667969,  1379.3145752 ],
#          [ 1335.03198242,  1334.09887695,  1333.40063477, ...,
#            1338.96582031,  1337.49902344,  1336.17565918],
#          [ 1249.10266113,  1247.12695312,  1246.63330078, ...,
#            1263.3548584 ,  1257.34521484,  1252.54003906],
#          ...,
#          [ 1067.3380127 ,  1062.1048584 ,  1057.89294434, ...,
#            1084.82861328,  1079.12426758,  1073.15722656],
#          [ 1070.8458252 ,  1071.05102539,  1071.9576416 , ...,
#            1074.44177246,  1072.56164551,  1071.3527832 ],
#          [ 1107.98059082,  1109.19909668,  1110.34033203, ...,
#            1103.9564209 ,  1105.34924316,  1106.69396973]],
#
#         [[ 1379.55541992,  1379.7611084 ,  1379.95812988, ...,
#            1378.90136719,  1379.12390137,  1379.34240723],
#          [ 1335.05700684,  1334.12390137,  1333.42602539, ...,
#            1338.99084473,  1337.52404785,  1336.20068359],
#          [ 1249.11120605,  1247.13903809,  1246.64990234, ...,
#            1263.35913086,  1257.34985352,  1252.54614258],
#          ...,
#          [ 1067.34338379,  1062.10888672,  1057.89575195, ...,
#            1084.83752441,  1079.13220215,  1073.16394043],
#          [ 1070.87756348,  1071.08435059,  1071.99267578, ...,
#            1074.46691895,  1072.5892334 ,  1071.38244629],
#          [ 1107.9810791 ,  1109.19787598,  1110.33752441, ...,
#            1103.96228027,  1105.35327148,  1106.69628906]],
#
#         [[           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          ...,
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan]]],
#
#
#        [[[  170.85112   ,   170.84634399,   170.84062195, ...,
#             170.85948181,   170.85771179,   170.85491943],
#          [  170.74700928,   170.74700928,   170.74047852, ...,
#             170.70657349,   170.72668457,   170.74023438],
#          [  170.66903687,   170.74481201,   170.79293823, ...,
#             170.31959534,   170.45072937,   170.56930542],
#          ...,
#          [  169.83161926,   169.86373901,   169.87998962, ...,
#             169.66390991,   169.72836304,   169.7855072 ],
#          [  169.640625  ,   169.61631775,   169.59129333, ...,
#             169.69993591,   169.68325806,   169.66323853],
#          [  169.57020569,   169.5789032 ,   169.5887146 , ...,
#             169.55140686,   169.55641174,   169.56268311]],
#
#         [[  166.33279419,   166.42958069,   166.52793884, ...,
#             166.05917358,   166.1468811 ,   166.23831177],
#          [  164.67440796,   164.97213745,   165.2709198 , ...,
#             163.81793213,   164.09408569,   164.38067627],
#          [  164.5296936 ,   165.12387085,   165.63140869, ...,
#             162.39038086,   163.14143372,   163.86248779],
#          ...,
#          [  160.78993225,   160.89144897,   160.93286133, ...,
#             160.22253418,   160.44247437,   160.6363678 ],
#          [  159.28634644,   159.17247009,   159.05097961, ...,
#             159.54312134,   159.47491455,   159.3883667 ],
#          [  158.54808044,   158.57102966,   158.60003662, ...,
#             158.51712036,   158.52101135,   158.53135681]],
#
#         [[  182.01715088,   182.37619019,   182.74423218, ...,
#             181.02101135,   181.3369751 ,   181.6698761 ],
#          [  178.19923401,   179.35955811,   180.5411377 , ...,
#             174.99179077,   176.00114441,   177.07493591],
#          [  180.33758545,   182.26768494,   184.01011658, ...,
#             173.80960083,   176.05937195,   178.25334167],
#          ...,
#          [  172.37632751,   172.85694885,   173.2056427 , ...,
#             170.41796875,   171.12442017,   171.78858948],
#          [  168.5010376 ,   168.35957336,   168.1681366 , ...,
#             168.55819702,   168.60507202,   168.58479309],
#          [  164.12139893,   164.1837616 ,   164.25331116, ...,
#             163.98190308,   164.02008057,   164.06669617]],
#
#         ...,
#         [[ 1382.72473145,  1383.28405762,  1383.78173828, ...,
#            1380.72229004,  1381.43896484,  1382.1081543 ],
#          [ 1349.3380127 ,  1348.49206543,  1347.72497559, ...,
#            1352.05090332,  1351.15002441,  1350.234375  ],
#          [ 1273.67590332,  1271.2088623 ,  1269.82995605, ...,
#            1286.71484375,  1281.57189941,  1277.16955566],
#          ...,
#          [ 1073.37805176,  1069.95019531,  1067.45080566, ...,
#            1085.75769043,  1081.6237793 ,  1077.38671875],
#          [ 1076.45410156,  1077.27502441,  1078.76745605, ...,
#            1078.0279541 ,  1076.84924316,  1076.31518555],
#          [ 1110.17224121,  1111.69567871,  1113.16442871, ...,
#            1105.39001465,  1107.00732422,  1108.60546875]],
#
#         [[ 1382.74755859,  1383.30761719,  1383.80603027, ...,
#            1380.74230957,  1381.46008301,  1382.13012695],
#          [ 1349.36425781,  1348.51879883,  1347.75219727, ...,
#            1352.07641602,  1351.17578125,  1350.26049805],
#          [ 1273.69055176,  1271.22705078,  1269.85266113, ...,
#            1286.72424316,  1281.58215332,  1277.18151855],
#          ...,
#          [ 1073.39086914,  1069.96179199,  1067.46130371, ...,
#            1085.77258301,  1081.63830566,  1077.4005127 ],
#          [ 1076.49145508,  1077.31420898,  1078.8079834 , ...,
#            1078.05859375,  1076.88232422,  1076.35058594],
#          [ 1110.18322754,  1111.70556641,  1113.1730957 , ...,
#            1105.40441895,  1107.02062988,  1108.61767578]],
#
#         [[           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          ...,
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan],
#          [           nan,            nan,            nan, ...,
#                      nan,            nan,            nan]]]], dtype=float32)

# %%
ne.max()
# Out:
# 2578788.5

# %%
tn.max()
# Out:
# 1385.3248

# %%
tn.compress(~tn.mask.ravel()).shape
# Out:
# (1741824,)

# %%
tiegcm.set_variable_boundary_condition('TN',verbose = True)
# Out:
# setting boundary condition: TN average <class 'numpy.ma.core.MaskedArray'>
# south min, max 163.18617079 1378.60698785
# north min, max 156.228732639 1156.09700521
# after south insert, min, max 0.0 1e+36
# average min,max 0.0 1e+36

# %% [markdown]
# # Mass density at any height h
# $$ H_X = kT^{bndy}/M_Xg $$
#
# $$ n_X(h) = n_X^{bndy}\times \exp((h^{bndy}-h)/H_X) [m^{-3}] $$
#
# $$ \rho(h) = 1.66053 \times 10^{-27} \times ( 16 \times n_0(h)+ 32 \times n_{O_2}(h) + 28 \times n_{N_2}(h) )$$

# %%
test_file = "sample_data/jasoon_shim_052317_IT_10/out/s001.nc"
tiegcm = TIEGCM(test_file)

# %%
z_max = tiegcm.z.max()
z_test = 1.1*z_max

point = Point3D(z_test, -20.5, .5)

variable_name = 'DEN'
time = 3.5

den = tiegcm.time_interpolate(point, variable_name, time)
den
# Out:
# 1.1389832474906783e-16

# %% [markdown]
# In meteorology, mixing ratio usually is defined as the mass of a constituent mi divided by the total mass of all other constituents in a mixture.
#
# $$ mmr = m_i/(m_{tot} - m_i) $$
#
# Therefore,
# $$ m_i = mmr(m_{tot} - m_i) = mmr \cdot m_{tot} - mmr \cdot m_i $$
# $$ m_i(1 + mmr) = mmr \cdot m_{tot} $$
# $$ m_i = mmr \cdot m_{tot}/(1+mmr) $$

# %% [markdown]
# ### Mass density of molecular oxygen

# %%
mmr_o = tiegcm.time_interpolate(point, 'O1', time)

den_o = mmr_o*den/(1+mmr_o)
den_o, den
# Out:
# (5.194653160011195e-17, 1.1389832474906783e-16)

# %%
def mass_density(self, point, variable_name, time):
    mmr_x = self.time_interpolate(point, variable_name, time)
    density_tot = self.time_interpolate(point, 'DEN', time)
    den_x = mmr_x*density_tot/(1+mmr_x)
    return den_x

# %%
mass_density(tiegcm, point, 'O1', time)
# Out:
# 5.194653160011195e-17
