# %% [markdown]
# # TIEGCM analysis and visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Note: TIEGCM requires netcdf4
#
#     pip install netcdf4

# %%
from netCDF4 import Dataset

# %%
from tiegcm.tiegcm import TIEGCM

# %%
ls -hl ~/Downloads/2013.03.01.tie-gcm.data/
# Out:
# total 2043904
# -rw-r--r--@ 1 apembrok  staff   232M Sep 25  2018 s000.nc
# -rwxr-xr-x@ 1 apembrok  staff   239M Sep 17  2018 s001.nc*
# -rwxr-xr-x@ 1 apembrok  staff   239M Sep 17  2018 s002.nc*
# -rwxr-xr-x@ 1 apembrok  staff   239M Sep 17  2018 s003.nc*

# %% [markdown]
# ## Usage
#
# For spatial interpolation for a single file, use the `TIEGCM` class.

# %%
fname = '/Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s003.nc'

# %%
tiegcm = TIEGCM(fname)
# Out:
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s003.nc

# %%
xlat = -3.69857
xlon = -156.48846
xalt = 360.10342*1e5 #cm

t = tiegcm.ut.mean()

# %%
tiegcm.density(xlat, xlon, xalt, t)
# Out:
# 5.435106369980757e-15

# %% [markdown]
# To perform time interpolation over a directory of files, use the `Model_Manager` class

# %%
from tiegcm.tiegcm import TIEGCM, Model_Manager
import pandas as pd

test_directory = '~/Downloads/2013.03.01.tie-gcm.data/'

mm = Model_Manager(test_directory)

print(mm.file_times.values())

mm.file_times.values()

times = pd.date_range(start ='2013-03-01 00:20:00', 
                      end = '2013-03-01 08:00:00', 
                      freq = '1S')

result = [mm.density(xlat, xlon, xalt,  t) for t in times]
# Out:
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s000.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s001.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s002.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s003.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s000.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s001.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s002.nc
# initializing tiegcm with /Users/apembrok/Downloads/2013.03.01.tie-gcm.data/s003.nc
# model manager initialized
# current time (Timestamp('2013-02-28 16:20:00'), Timestamp('2013-03-01 00:00:00'))
# ...

# %%
result
# Out:
# [5.2857337782379625e-15,
#  5.285750638916914e-15,
#  5.2857674994919345e-15,
#  5.285784359963021e-15,
#  5.2858012203301775e-15,
#  5.285818080593404e-15,
#  5.285834940752697e-15,
#  5.2858518008080596e-15,
#  5.2858686607594895e-15,
#  5.285885520606979e-15,
#  5.2859023803505545e-15,
#  5.28591923999019e-15,
#  5.285936099525894e-15,
#  5.2859529589576656e-15,
#  5.285969818285505e-15,
#  5.285986677509415e-15,
#  5.286003536629392e-15,
#  5.286020395645438e-15,
#  5.2860372545575515e-15,
#  5.286054113365733e-15,
#  5.286070972069977e-15,
#  5.286087830670305e-15,
#  5.286104689166691e-15,
#  5.286121547559146e-15,
#  5.286138405847671e-15,
#  5.286155264032263e-15,
#  5.286172122112924e-15,
#  5.286188980089654e-15,
#  5.2862058379624515e-15,
#  5.286222695731318e-15,
#  5.286239553396252e-15,
#  5.286256410957254e-15,
#  5.2862732684143265e-15,
#  5.286290125767465e-15,
#  5.286306983016673e-15,
#  5.2863238401619425e-15,
#  5.286340697203294e-15,
#  5.286357554140708e-15,
# ...
